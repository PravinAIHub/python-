# %%
from pravin import multiplefunctions

# %%
multiplefunctions().area()
# Out:
# Height 32
# breath 34
# Area formula:height*breath/2
# Area of triangle: 544.0

# %%
from pravin import multiplefunctions
multiplefunctions().perimeter()
# Out:
# height1:2
# height2:4
# breath:4
# perimeter of triangle: 10

# %%
from pravin import multiplefunctions
multiplefunctions().percentage()
# Out:
# subject1 100
# subject2 100
# subject3 100
# subject4 100
# subject5 100
# Total 500
# percentage 100.0

# %%
from pravin import multiplefunctions
multiplefunctions().eligibilityformarriage()
# Out:
# enter your gender male
# enter your age 50
